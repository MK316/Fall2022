# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Fall2022/blob/main/nltk_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NLTK Practice
#
# Add code cells to follow the instructions.
#
# [file link](https://docs.google.com/viewer?a=v&pid=sites&srcid=bWVubG9hdGhlcnRvbmhzLmNvbXxtcnMtYmVyZ2hvdXNlLWVuZ2xpc2gtMjAxM3xneDo0MjM5ZDNlNjFlNjExM2Ey)
#
# => download the pdf file and upload it to your colab folder (folder icon on the left)

# %% [markdown]
# # Pre-processing the file
#
# - pdf to text

# %%
# !pip install pymupdf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import fitz

# %%
DIGITIZED_FILE = "/content/TheGreatGatsby.pdf"

# %%
# This code works well: extracting a single file
total =""
with fitz.open(DIGITIZED_FILE) as doc:
    for page in doc:
        text = page.get_text()
        total = total + text
        # print(text)

# %%
# print(text)

# %%
# Save the total text as a txt file
with open('thegreatgatsby.txt', 'w') as f:
    f.write(total)

# %% [markdown]
# Using {pymupdf}{fitz}

# %% [markdown]
# ##[1] text to bring (two ways)
#
# # 1) Github file to read: a text file on your github account and use it as mytext
#
# [File link](https://raw.githubusercontent.com/MK316/Fall2022/main/thegreatgatsby.txt)
#
# {base64}, {requests}
#
# url = ""
# mytext = myread(url)
#
# # 2) copy and paste
#
# mytext = input()

# %%
# mytext = input()
# Out:
# Download free eBooks of classic literature, books and  novels at Planet eBook. Subscribe to our free eBooks blog  and email newsletter. The Great Gatsby By F. Scott Fitzgerald The Great Gatsby  Then wear the gold hat, if that will move her;  If you can bounce high, bounce for her too,  Till she cry ‘Lover, gold-hatted, high-bouncing lover,  I must have you!’ —THOMAS PARKE D’INVILLIERS  Free eBooks at Planet eBook.com Chapter 1 I n my younger and more vulnerable years my father gave  me some advice that I’ve been turning over in my mind  ever since. ‘Whenever you feel like criticizing any one,’ he told me,  ‘just remember that all the people in this world haven’t had  the advantages that you’ve had.’ He didn’t say any more but we’ve always been unusually  communicative in a reserved way, and I understood that he  meant a great deal more than that. In consequence I’m in- clined to reserve all judgments, a habit that has opened up  many curious natures to me and also made me the victim 
# ...

# %% [markdown]
# ## [2] import {nltk}, download 'punkt' from {nltk}, import word_tokenize, sent_tokenize from {nltk}

# %%
import nltk
from nltk import word_tokenize, sent_tokenize
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ##Tasks: Getting Word cloud, string count, word count, sentence count
#
# e.g., word_tokenize(mytext)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
mytext = total
wc = WordCloud().generate(mytext) 
plt.imshow(wc)

# %%
words = word_tokenize(mytext)
len(words)
sents = sent_tokenize(mytext)
len(sents)
# Out:
# 2478

# %% [markdown]
# ## [3] Getting word frequency and save it as 'WF01.csv' on your laptop

# %%
from nltk.tokenize import RegexpTokenizer
retokenize =RegexpTokenizer("[\w]+")
words = retokenize.tokenize(mytext)
len(words)
# Out:
# 51719

# %%
# import stopwords from nltk.corpus

from nltk.corpus import stopwords
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
words_as = [w for w in words if not w.lower() in stopwords.words('english')]
len(words_as)
# Out:
# 25019

# %%
# words_as

# %%
newtext = ' '.join(words_as)

# %%
mytext = newtext
wc = WordCloud().generate(mytext) 
plt.imshow(wc)

# %%
fd = nltk.FreqDist(words_as).most_common(10)
fd
# Out:
# [('Gatsby', 355),
#  ('said', 234),
#  ('Tom', 191),
#  ('Daisy', 183),
#  ('one', 158),
#  ('like', 119),
#  ('man', 119),
#  ('back', 109),
#  ('came', 106),
#  ('1', 99)]

# %%
type(fd)
# Out:
# list

# %% [markdown]
# dict.values()
# dic['Key']
#
# tuple data

# %%
fd[0][1]
# Out:
# 355

# %%
import pandas as pd

fd = nltk.FreqDist(words_as).most_common()

df = pd.DataFrame()
word = []
count = []
for i in range(0,len(fd)):
  word.append(fd[i][0])
  count.append(fd[i][1])
df['Word'] = word
df['Freq'] = count

# %%
df.tail()
# Out:
#           Word  Freq
# 6444  orgastic     1
# 6445   recedes     1
# 6446   current     1
# 6447     borne     1
# 6448       END     1
